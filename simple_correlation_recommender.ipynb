# %%
import numpy as np
import pandas as pd

# %%
frame = pd.read_csv('restaurant_consumer_data/rating_final.csv')
cuisine = pd.read_csv('restaurant_consumer_data/chefmozcuisine.csv')
geodata = pd.read_csv('restaurant_consumer_data/geoplaces2.csv',encoding='mbcs')

# %%
frame.head() #rating ranges from 0 to 2 0 being worst and 2 being the best
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2
